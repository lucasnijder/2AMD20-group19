# %%
import pandas as pd
import math

# %%
munis = pd.read_csv('C:/Users/20175878/Documents/GitHub/2AMD20-group19/2_preprocessed_data/Municipalities.csv')

# %%
energy_usage = pd.read_csv('C:/Users/20175878/Documents/GitHub/2AMD20-group19/2_preprocessed_data/EnergyUsage.csv')
joined = munis.merge(energy_usage.drop('Gemeentecode', axis=1), on='Gemeentenaam', how='left')
joined
# Out:
#      Gemeentecode     Gemeentenaam  Provinciecode  Provincienaam  \
# 0            1680      AA EN HUNZE             22        DRENTHE
# 1             358         AALSMEER             27  NOORD-HOLLAND
# 2             197           AALTEN             25     GELDERLAND
# 3              59    ACHTKARSPELEN             21      FRIESLAND
# 4             482     ALBLASSERDAM             28   ZUID-HOLLAND
# ..            ...              ...            ...            ...
# 350           879          ZUNDERT             30  NOORD-BRABANT
# 351           301          ZUTPHEN             25     GELDERLAND
# 352          1896  ZWARTEWATERLAND             23     OVERIJSSEL
# 353           642      ZWIJNDRECHT             28   ZUID-HOLLAND
# 354           193           ZWOLLE             23     OVERIJSSEL
#
#      GemiddeldAardgasverbruik  GemiddeldElektriciteitsverbruik
# 0                    632890.0                        1093470.0
# 1                    148310.0                         319190.0
# 2                    325310.0                         690380.0
# 3                    263420.0                         482300.0
# 4                    255920.0                         645420.0
# ..                        ...                              ...
# 350                  186160.0                         404530.0
# 351                  370140.0                         756230.0
# 352                  361420.0                         742320.0
# 353                  656700.0                        1468820.0
# 354                  772210.0                        1698240.0
#
# [355 rows x 6 columns]

# %%
total_weather = pd.read_csv('C:/Users/20175878/Documents/GitHub/2AMD20-group19/2_preprocessed_data/TotaalWeerStation.csv')
weerstation_per_gemeente = pd.read_csv('C:/Users/20175878/Documents/GitHub/2AMD20-group19/2_preprocessed_data/weerstation_per_gemeente.csv')

joined = joined.merge(weerstation_per_gemeente, on='Gemeentenaam', how='left')
joined = joined.merge(total_weather, on='WeerStation', how='left')
joined
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\20175878\Documents\GitHub\2AMD20-group19\create_map_data.ipynb Cell 4' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/20175878/Documents/GitHub/2AMD20-group19/create_map_data.ipynb#ch0000003?line=0'>1</a> total_weather = pd.read_csv('C:/Users/20175878/Documents/GitHub/2AMD20-group19/2_preprocessed_data/TotaalWeerStation.csv')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/20175878/Documents/GitHub/2AMD20-group19/create_map_data.ipynb#ch0000003?line=1'>2</a> weerstation_per_gemeente = pd.read_csv('C:/Users/20175878/Documents/GitHub/2AMD20-group19/2_preprocessed_data/weerstation_per_gemeente.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/20175878/Documents/GitHub/2AMD20-group19/create_map_data.ipynb#ch0000003?line=3'>4</a> joined = joined.merge(weerstation_per_gemeente, on='Gemeentenaam', how='left')
#       <a href='vscode-notebook-cell:/c%3A/Users/20175878/Documents/GitHub/2AMD20-group19/create_map_data.ipynb#ch0000003?line=4'>5</a> joined = joined.merge(total_weather, on='WeerStation', how='left')
#
# File c:\Users\20175878\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\20175878\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\20175878\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Users\20175878\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\20175878\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File c:\Users\20175878\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/20175878/Documents/GitHub/2AMD20-group19/2_preprocessed_data/weerstation_per_gemeente.csv'

# %%
inhabitants = pd.read_csv('C:/Users/20175878/Documents/GitHub/2AMD20-group19/2_preprocessed_data/InhabitantsMunicipality.csv')
joined = joined.merge(inhabitants, on='Gemeentenaam', how='left')
joined
# Out:
#      Gemeentecode     Gemeentenaam  Provinciecode  Provincienaam  \
# 0            1680      AA EN HUNZE             22        DRENTHE
# 1             358         AALSMEER             27  NOORD-HOLLAND
# 2             197           AALTEN             25     GELDERLAND
# 3              59    ACHTKARSPELEN             21      FRIESLAND
# 4             482     ALBLASSERDAM             28   ZUID-HOLLAND
# ..            ...              ...            ...            ...
# 350           879          ZUNDERT             30  NOORD-BRABANT
# 351           301          ZUTPHEN             25     GELDERLAND
# 352          1896  ZWARTEWATERLAND             23     OVERIJSSEL
# 353           642      ZWIJNDRECHT             28   ZUID-HOLLAND
# 354           193           ZWOLLE             23     OVERIJSSEL
#
#      GemiddeldAardgasverbruik  GemiddeldElektriciteitsverbruik  WeerStation  \
# 0                    632890.0                        1093470.0        EELDE
# 1                    148310.0                         319190.0     SCHIPHOL
# 2                    325310.0                         690380.0       HUPSEL
# 3                    263420.0                         482300.0   LEEUWARDEN
# 4                    255920.0                         645420.0    ROTTERDAM
# ..                        ...                              ...          ...
# 350                  186160.0                         404530.0  GILZE-RIJEN
# 351                  370140.0                         756230.0       DEELEN
# 352                  361420.0                         742320.0    MARKNESSE
# 353                  656700.0                        1468820.0    ROTTERDAM
# 354                  772210.0                        1698240.0    MARKNESSE
#
#     pctzon_gemiddeld  FG_gemiddeld  Inwoneraantal Groot, middelgroot en klein
# 0               35.6           4.2            NaN                         NaN
# 1               37.7           5.0        31499.0                       Klein
# 2               36.3           3.4            NaN                         NaN
# 3               38.0           4.7            NaN                         NaN
# 4               37.1           4.4            NaN                         NaN
# ..               ...           ...            ...                         ...
# 350             36.9           3.7            NaN                         NaN
# 351             35.0           3.8        47537.0                       Klein
# 352             38.2           4.2            NaN                         NaN
# 353             37.1           4.4        44586.0                       Klein
# 354             38.2           4.2       126116.0                       Groot
#
# [355 rows x 11 columns]

# %%
postcodes = pd.read_csv('C:/Users/20175878/Documents/GitHub/2AMD20-group19/2_preprocessed_data/postcodeMunicipality.csv')
restricties = pd.read_csv('C:/Users/20175878/Documents/GitHub/2AMD20-group19/2_preprocessed_data/Restrictions.csv')

pr = postcodes.merge(restricties, on='Postcode', how='left')
pr_grouped = pr.groupby('Gemeentecode')['Kleur'].agg(list)

def remove_nans(mylist):
    cleaned_list = [x for x in mylist if str(x) != 'nan']

    if len(cleaned_list) == 0:
        return 'NO RESTRICTIONS'
    else:
        return max(set(cleaned_list), key = cleaned_list.count)

pr_grouped = pr_grouped.apply(remove_nans).reset_index()

pr_grouped
joined = joined.merge(pr_grouped, on='Gemeentecode', how='left')
joined
# Out:
#      Gemeentecode     Gemeentenaam  Provinciecode  Provincienaam  \
# 0            1680      AA EN HUNZE             22        DRENTHE
# 1             358         AALSMEER             27  NOORD-HOLLAND
# 2             197           AALTEN             25     GELDERLAND
# 3              59    ACHTKARSPELEN             21      FRIESLAND
# 4             482     ALBLASSERDAM             28   ZUID-HOLLAND
# ..            ...              ...            ...            ...
# 350           879          ZUNDERT             30  NOORD-BRABANT
# 351           301          ZUTPHEN             25     GELDERLAND
# 352          1896  ZWARTEWATERLAND             23     OVERIJSSEL
# 353           642      ZWIJNDRECHT             28   ZUID-HOLLAND
# 354           193           ZWOLLE             23     OVERIJSSEL
#
#      GemiddeldAardgasverbruik  GemiddeldElektriciteitsverbruik  WeerStation  \
# 0                    632890.0                        1093470.0        EELDE
# 1                    148310.0                         319190.0     SCHIPHOL
# 2                    325310.0                         690380.0       HUPSEL
# 3                    263420.0                         482300.0   LEEUWARDEN
# 4                    255920.0                         645420.0    ROTTERDAM
# ..                        ...                              ...          ...
# 350                  186160.0                         404530.0  GILZE-RIJEN
# 351                  370140.0                         756230.0       DEELEN
# 352                  361420.0                         742320.0    MARKNESSE
# 353                  656700.0                        1468820.0    ROTTERDAM
# 354                  772210.0                        1698240.0    MARKNESSE
#
#     pctzon_gemiddeld  FG_gemiddeld  Inwoneraantal Groot, middelgroot en klein  \
# 0               35.6           4.2            NaN                         NaN
# 1               37.7           5.0        31499.0                       Klein
# 2               36.3           3.4            NaN                         NaN
# 3               38.0           4.7            NaN                         NaN
# 4               37.1           4.4            NaN                         NaN
# ..               ...           ...            ...                         ...
# 350             36.9           3.7            NaN                         NaN
# 351             35.0           3.8        47537.0                       Klein
# 352             38.2           4.2            NaN                         NaN
# 353             37.1           4.4        44586.0                       Klein
# 354             38.2           4.2       126116.0                       Groot
#
#                Kleur
# 0               GEEL
# 1    NO RESTRICTIONS
# 2    NO RESTRICTIONS
# 3    NO RESTRICTIONS
# 4    NO RESTRICTIONS
# ..               ...
# 350           ORANJE
# 351  NO RESTRICTIONS
# 352             ROOD
# 353  NO RESTRICTIONS
# 354             ROOD
#
# [355 rows x 12 columns]

# %%
sun = pd.read_csv('C:/Users/20175878/Documents/GitHub/2AMD20-group19/2_preprocessed_data/sun.csv')
joined = joined.merge(sun, on='Gemeentenaam', how='left')
joined
# Out:
#      Gemeentecode     Gemeentenaam  Provinciecode  Provincienaam  \
# 0            1680      AA EN HUNZE             22        DRENTHE
# 1             358         AALSMEER             27  NOORD-HOLLAND
# 2             197           AALTEN             25     GELDERLAND
# 3              59    ACHTKARSPELEN             21      FRIESLAND
# 4             482     ALBLASSERDAM             28   ZUID-HOLLAND
# ..            ...              ...            ...            ...
# 350           879          ZUNDERT             30  NOORD-BRABANT
# 351           301          ZUTPHEN             25     GELDERLAND
# 352          1896  ZWARTEWATERLAND             23     OVERIJSSEL
# 353           642      ZWIJNDRECHT             28   ZUID-HOLLAND
# 354           193           ZWOLLE             23     OVERIJSSEL
#
#      GemiddeldAardgasverbruik  GemiddeldElektriciteitsverbruik  WeerStation  \
# 0                    632890.0                        1093470.0        EELDE
# 1                    148310.0                         319190.0     SCHIPHOL
# 2                    325310.0                         690380.0       HUPSEL
# 3                    263420.0                         482300.0   LEEUWARDEN
# 4                    255920.0                         645420.0    ROTTERDAM
# ..                        ...                              ...          ...
# 350                  186160.0                         404530.0  GILZE-RIJEN
# 351                  370140.0                         756230.0       DEELEN
# 352                  361420.0                         742320.0    MARKNESSE
# 353                  656700.0                        1468820.0    ROTTERDAM
# 354                  772210.0                        1698240.0    MARKNESSE
#
#     pctzon_gemiddeld  FG_gemiddeld  Inwoneraantal Groot, middelgroot en klein  \
# 0               35.6           4.2            NaN                         NaN
# 1               37.7           5.0        31499.0                       Klein
# 2               36.3           3.4            NaN                         NaN
# 3               38.0           4.7            NaN                         NaN
# 4               37.1           4.4            NaN                         NaN
# ..               ...           ...            ...                         ...
# 350             36.9           3.7            NaN                         NaN
# 351             35.0           3.8        47537.0                       Klein
# 352             38.2           4.2            NaN                         NaN
# 353             37.1           4.4        44586.0                       Klein
# 354             38.2           4.2       126116.0                       Groot
#
#                Kleur  AantalInstallatiesBijWoningen  \
# 0               GEEL                         7634.0
# 1    NO RESTRICTIONS                         4866.0
# 2    NO RESTRICTIONS                         5919.0
# 3    NO RESTRICTIONS                         5151.0
# 4    NO RESTRICTIONS                         1759.0
# ..               ...                            ...
# 350           ORANJE                         3513.0
# 351  NO RESTRICTIONS                         8097.0
# 352             ROOD                         3404.0
# 353  NO RESTRICTIONS                         4229.0
# 354             ROOD                        28684.0
#
#      OpgesteldVermogenVanZonnepanelen
# 0                             29820.0
# 1                             17104.0
# 2                             22730.0
# 3                             22527.0
# 4                              5507.0
# ..                                ...
# 350                           15257.0
# 351                           23831.0
# 352                           11751.0
# 353                           13015.0
# 354                           87308.0
#
# [355 rows x 14 columns]

# %%
joined.to_csv('C:/Users/20175878/Documents/GitHub/2AMD20-group19/3_map_data/map_dataset.csv', index=False)
